# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I'm choosing Lane 2: Refresh / Content Opportunity Scoring. This lane asks which pages should be reviewed first for refresh, expansion, or monitoring. I picked it because the starter notebooks (01 and 02) already walked me through this exact workflow — comparing a hand-written rule against a learned model to rank pages — and I want to build on that foundation rather than start from scratch. It also has the deepest, most reliable data coverage in the warehouse (impressions and content metadata are dense compared to AI-session data, for example).

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which content pages should a review team look at first, out of thousands, given they only have time to review a limited number each week (a review queue).
#
# Who acts on it: A content/SEO reviewer, who receives a ranked list of pages and decides whether to refresh, expand, or leave each one.
#
# Cost of a wrong call: If we rank a healthy page too high, the reviewer wastes limited time on a page that didn't need attention (opportunity cost — a real declining page waits longer). If we rank a genuinely declining page too low, it keeps losing visibility unnoticed until the loss is harder to recover from.
#
# Unit of analysis: one content page (content_hash_id), scored using its trailing performance window.
#
#
# This is not just "train a model" — before any modeling, I need a clear data contract (which fields are safe to use), a transparent baseline rule to compare against, and a validation design that proves any model actually beats that baseline on unseen clients. The model is one step in a larger decision-support pipeline, not the goal itself.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/ZarifaMusayeva/ml-assignments/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)
print("Total pages:", len(df))
print(df["trend_direction"].value_counts())
print("Average impressions_90d:", df["impressions_90d"].mean())
# Out:
# Total pages: 30000
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
# Average impressions_90d: 5200.3663

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can claim: this project produces a decision-support ranking — a prioritized list of pages worth reviewing, based on observed signals like impressions, clicks, position, and trend. My results are observational, not experimental.
#
# What I cannot claim: that refreshing a page will cause it to recover (that requires an actual experiment, not this data). I also cannot claim to have discovered a Google ranking algorithm factor, or that a model "understands" content — only that certain observed signals correlate with movement in visibility or engagement.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
